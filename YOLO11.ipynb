# %% [markdown]
# <a href="https://colab.research.google.com/github/FDKAJUM/raicamp2025/blob/main/YOLO11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup YOLO11
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/requirements.txt) and check software and hardware.

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()

# %% [markdown]
# # 1. Predict ( Test Setup YOLO11)
#
# YOLOv8 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) and other details in the [YOLO11 Predict Docs](https://docs.ultralytics.com/modes/train/).

# %%
# Run inference on an image with YOLOv11n
# !yolo predict model=yolo11n.pt source='https://ultralytics.com/images/bus.jpg'

# %% [markdown]
# # 2. Add Zip Data Export YOLO11 for Roboflow

# %%
import zipfile
from google.colab import files

# %cd /content
uploaded = files.upload()
for filename in uploaded.keys():
  pass

zip_ref = zipfile.ZipFile(filename, 'r')
zip_ref.extractall("/content/")

# %% [markdown]
# # 3. Train Data Roboflow

# %%
# Validate YOLOv8n
# !yolo train model=yolo11n.pt data=data.yaml epochs=372 imgsz=640
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # 4. Test Model Training

# %%
# !yolo detect predict model=/content/runs/detect/train5/weights/best.pt conf=0.1 imgsz=640 source='/content/test/images/'
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/3 /content/test/images/yt-qCY8_SQ93O8-0002_jpg.rf.8e93d028008339dd78701a773c7753b1.jpg: 640x640 2 1s, 12.1ms
# image 2/3 /content/test/images/yt-qCY8_SQ93O8-0003_jpg.rf.47dd373e00d518e81940ad74572a9ec7.jpg: 640x640 2 1s, 9.7ms
# image 3/3 /content/test/images/yt-qCY8_SQ93O8-0031_jpg.rf.aadbff5b48c64809056c9a4482117f66.jpg: 640x640 1 1, 10.2ms
# Speed: 2.4ms preprocess, 10.7ms inference, 49.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 5. Test Video for Model Ai

# %%
# !yolo detect predict model=/content/runs/detect/train5/weights/best.pt  conf=0.1 imgsz=640 source='/content/drive/MyDrive/1A/DataTestENV2.mp4'
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/cfg/__init__.py", line 986, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py", line 560, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/predictor.py", line 190, in predict_cli
#     for _ in gen:  # sourcery skip: remove-empty-nested-block, noqa
# ...
